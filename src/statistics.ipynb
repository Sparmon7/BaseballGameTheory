# %% [markdown]
# # Statistics
# Let's take a look at some statistics of the data we have.
#
# The code in here is a bit messy and a bit AI generated.

# %%
from collections import defaultdict
from typing import Callable

from tqdm.notebook import tqdm

import torch
from torch.utils.data import DataLoader

import numpy as np

from src.data.data_loading import BaseballData
from src.data.datasets import SwingResult, PitchDataset
from src.distributions.batter_patience import get_batter_patience_set, BatterSwings, batter_patience_map
from src.distributions.pitcher_control import get_pitch_control_sets, PitcherControl
from src.model.state import PitchResult
from src.model.pitch_type import PitchType
from src.model.zones import Zones, default
from src.model.pitch import Pitch
from src.distributions.swing_outcome import SwingOutcome, get_swing_outcome_dataset

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as mcolors

# %%
bd = BaseballData(processed_data_dir='../processed_data/')
# Out:
# Loading pitches:   0%|          | 0/17 [00:00<?, ?it/s]

# %%
pitchers_by_obp = sorted(filter(lambda p: p[1].obp_percentile is not None, bd.pitchers.items()), key=lambda p: p[1].obp_percentile)
batters_by_obp = sorted(filter(lambda p: p[1].obp_percentile is not None, bd.batters.items()), key=lambda p: p[1].obp_percentile)

print('Best pitcher:', pitchers_by_obp[-1][0], pitchers_by_obp[-1][1].obp_percentile, pitchers_by_obp[-1][1].obp)
print('Worst pitcher:', pitchers_by_obp[0][0], pitchers_by_obp[0][1].obp_percentile, pitchers_by_obp[0][1].obp)
print('Best batter:', batters_by_obp[-1][0], batters_by_obp[-1][1].obp_percentile, batters_by_obp[-1][1].obp)
print('Worst batter:', batters_by_obp[0][0], batters_by_obp[0][1].obp_percentile, batters_by_obp[0][1].obp)
# Out:
# Best pitcher: 642585 0.9995029821073559 0.1484375
# Worst pitcher: 592464 0.0 0.3665338645418327
# Best batter: 608061 0.9994222992489891 0.3160919540229885
# Worst batter: 462102 0.0 0.04932735426008968

# %% [markdown]
# # Exploring Pitch Data

# %%
def visualize_zones(zones: Zones):
    """Visualizes the zones on a simple plot"""

    fig, ax = plt.subplots(figsize=(2, 2), dpi=100)
    for zone in zones.ZONES:
        if zone.is_strike:
            edge_color = 'red'
        elif zone.is_borderline:
            edge_color = 'green'
        else:
            edge_color = 'blue'

        Inf = float('inf')
        left = zone.left if zone.left != -Inf else zones.STRIKE_ZONE_LEFT - zones.STRIKE_ZONE_WIDTH / 2
        right = zone.right if zone.right != Inf else zones.STRIKE_ZONE_RIGHT + zones.STRIKE_ZONE_WIDTH / 2
        top = zone.top if zone.top != Inf else zones.STRIKE_ZONE_TOP + zones.STRIKE_ZONE_HEIGHT / 2
        bottom = zone.bottom if zone.bottom != -Inf else zones.STRIKE_ZONE_BOTTOM - zones.STRIKE_ZONE_HEIGHT / 2

        edge_rgb = mcolors.to_rgba(edge_color)
        face_color = edge_rgb[:3] + (0.5,)

        rect = patches.Rectangle((left, bottom), right - left, top - bottom,
                                 linewidth=1, edgecolor=edge_color, facecolor=face_color)
        ax.add_patch(rect)

    plt.xlim(-30, 30)
    plt.ylim(0, 60)
    plt.xlabel('Horizontal Position (inches)', fontsize=8)
    plt.ylabel('Vertical Position (inches)', fontsize=8)
    plt.title('Strike Zone Visualization')
    plt.grid(False)
    plt.show()

visualize_zones(Zones())

# %%
pitch_types = torch.zeros(len(PitchType))
pitch_type_locations = defaultdict(lambda: torch.zeros(Zones.DIMENSION, Zones.DIMENSION))
pitch_result_locations = defaultdict(lambda: torch.zeros(Zones.DIMENSION, Zones.DIMENSION))
pitch_results = torch.zeros(len(PitchResult))
expected_strikes = torch.zeros(Zones.DIMENSION, Zones.DIMENSION)

for pitch in tqdm(bd.pitches):
    if pitch.is_valid():
        coords = default.COMBINED_ZONES[pitch.zone_idx].coords[0]
        pitch_type_locations[pitch.type.value][coords] += 1
        pitch_result_locations[pitch.result.value][coords] += 1
        pitch_types[pitch.type.value] += 1
        pitch_results[pitch.result.value] += 1
        if pitch.game_state.strikes == 0 and pitch.game_state.balls == 3:
            expected_strikes[coords] += 1

zones = Zones()
for zone in zones.ZONES:
    if len(zone.coords) > 1:
        for coord in zone.coords[1:]:
            for locs in pitch_type_locations.values():
                locs[coord] = locs[zone.coords[0]]
            for locs in pitch_result_locations.values():
                locs[coord] = locs[zone.coords[0]]
            expected_strikes[coord] = expected_strikes[zone.coords[0]]
# Out:
#   0%|          | 0/11796345 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(1, len(PitchType), dpi=600)
for pt, locs in pitch_type_locations.items():
    ax[pt].imshow(locs, cmap='gray')
    ax[pt].set_title(PitchType(pt).name, fontsize=8)
    ax[pt].axis('off')
    
fig, ax = plt.subplots(1, len(PitchResult))
for pr, locs in pitch_result_locations.items():
    ax[pr].imshow(locs, cmap='gray')
    ax[pr].set_title(PitchResult(pr).name, fontsize=6)
    ax[pr].axis('off')

# %%
fig, ax = plt.subplots(1, 2, dpi=300)
fig.set_figwidth(12)

ax[0].bar([pr.name for pr in PitchResult], pitch_results)
ax[0].set_title('Pitch Results')

ax[1].bar([pt.name for pt in PitchType], pitch_types)
ax[1].set_title('Pitch Types')

for a in ax:
    for label in a.get_xticklabels():
        label.set_fontsize(5)

# %%
fig = plt.figure(dpi=100)
ax1 = fig.add_subplot(121)
ax1.imshow(expected_strikes, cmap='gray')
ax1.set_title('Pitches on 3-0 Count')
# Out:
# Text(0.5, 1.0, 'Pitches on 3-0 Count')

# %% [markdown]
# # Exploring the Learned Swing Result Distribution
# Let's examine the network's performance across different conditions, with known
# meaningful differences.

# %%
training_data, test_data = get_swing_outcome_dataset(bd)

conditions: dict[str, Callable[[Pitch], bool]] = {
    'all': (lambda p: True),
    '30': (lambda p: p.game_state.balls == 3 and p.game_state.strikes == 0),
    '02': (lambda p: p.game_state.balls == 0 and p.game_state.strikes == 2),
    'ball': (lambda p: not p.get_zone().is_strike),
    'strike': (lambda p: p.get_zone().is_strike),
    'strong pitcher vs weak batter': (lambda p: bd.pitchers[p.pitcher_id].obp_percentile is not None and bd.batters[p.batter_id].obp_percentile is not None and bd.pitchers[p.pitcher_id].obp_percentile > 2/3 and bd.batters[p.batter_id].obp_percentile < 1/3),
    'weak pitcher vs strong batter': (lambda p: bd.pitchers[p.pitcher_id].obp_percentile is not None and bd.batters[p.batter_id].obp_percentile is not None and bd.pitchers[p.pitcher_id].obp_percentile < 1/3 and bd.batters[p.batter_id].obp_percentile > 2/3),
    'bases empty': (lambda p: not p.game_state.first and not p.game_state.second and not p.game_state.third),
    'bases loaded': (lambda p: p.game_state.first and p.game_state.second and p.game_state.third),
}

matching_pitches = defaultdict(int)

actual_distribution = defaultdict(lambda: torch.zeros(len(SwingResult)))

for src_idx, pitch_data, _ in tqdm(test_data):
    for name, condition in conditions.items():
        src_pitch = bd.pitches[src_idx]
        if condition(src_pitch):
            matching_pitches[name] += 1
            actual_distribution[name][SwingResult.from_pitch_result(src_pitch.result)] += 1
# Out:
#   0%|          | 0/1071116 [00:00<?, ?it/s]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Might be necessary to switch to CPU due to issues with how Jupyter handles memory
# device = 'cpu'

model = SwingOutcome().to(device)
path = '../../model_weights/swing_outcome.pth'
model.load_state_dict(torch.load(path))
model.eval()

predicted_distribution = defaultdict(lambda: torch.zeros(len(SwingResult)).to(device))

dataloader = DataLoader(test_data, batch_size=512)
for batch_idx, (pitch_idx, pitch_data, target) in tqdm(enumerate(dataloader), total=len(dataloader)):
    data = [t.to(device) for t in pitch_data]
    outcome_tensor = model(*data, softmax=True)
    
    result_distributions = outcome_tensor.squeeze().tolist()
    if not isinstance(result_distributions[0], list):  # In case the batch is a single element
        result_distributions = [result_distributions]
        
    for i, result_distribution in enumerate(result_distributions):
        pitch = bd.pitches[pitch_idx[i]]
        for name, condition in conditions.items():
            if condition(pitch):
                predicted_distribution[name] += torch.tensor(result_distribution).to(device)
# Out:
#   0%|          | 0/2093 [00:00<?, ?it/s]

# %%
len(test_data)
# Out:
# 1071116

# %%
def get_distribution(distribution: dict[str, torch.Tensor], c_name: str):
    return distribution[c_name].cpu().detach().numpy() / matching_pitches[c_name]

def compare_conditions(condition1: str, condition2: str = None):
    swing_results = [sr.name for sr in SwingResult]
    x = np.arange(len(swing_results))  # the label locations
    width = 0.2  # the width of the bars

    fig, ax = plt.subplots(figsize=(12, 6), dpi=300)

    actual_distribution_c1 = get_distribution(actual_distribution, condition1)
    predicted_distribution_c1 = get_distribution(predicted_distribution, condition1)
    
    # Plot for condition1
    bars_actual_c1 = ax.bar(x - width / 2, actual_distribution_c1, width, label=f'Actual {condition1}', color='blue', edgecolor='black')
    bars_predicted_c1 = ax.bar(x + width / 2, predicted_distribution_c1, width, label=f'Predicted {condition1}', color='blue', hatch='\\', edgecolor='black')

    if condition2:
        actual_distribution_c2 = get_distribution(actual_distribution, condition2)
        predicted_distribution_c2 = get_distribution(predicted_distribution, condition2)
        
        # Bar positions for condition 2
        bars_actual_c2 = ax.bar(x + width*1.5, actual_distribution_c2, width, label=f'Actual {condition2}', color='red', edgecolor='black')
        bars_predicted_c2 = ax.bar(x + width*2.5, predicted_distribution_c2, width, label=f'Predicted {condition2}', color='red', hatch='\\', edgecolor='black')

        # Add text labels for condition 2
        for bar in bars_actual_c2:
            height = bar.get_height()
            ax.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.3f}', ha='center', va='bottom', fontsize=6)
        for bar in bars_predicted_c2:
            height = bar.get_height()
            ax.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.3f}', ha='center', va='bottom', fontsize=6)

    # Add text labels for condition 1
    for bar in bars_actual_c1:
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.3f}', ha='center', va='bottom', fontsize=6)
    for bar in bars_predicted_c1:
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.3f}', ha='center', va='bottom', fontsize=6)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_xlabel('Swing Results')
    ax.set_ylabel('Distribution')
    
    error = 'Total difference %s: %.2f%%' % (condition1, 100 * sum(list(abs(actual_distribution_c1 - predicted_distribution_c1))))
    if condition2:
        error += ', %s: %.2f%%' % (condition2, 100 * sum(list(abs(actual_distribution_c2 - predicted_distribution_c2))))
    
    ax.set_title('Swing Results by Condition \n' + error)
    ax.set_xticks(x)
    ax.set_xticklabels(swing_results)
    ax.set_ylim(0, 1)
    ax.legend()

    fig.tight_layout()
    plt.show()


compare_conditions('all')
compare_conditions('30', '02')
compare_conditions('ball', 'strike')
compare_conditions('strong pitcher vs weak batter', 'weak pitcher vs strong batter')
compare_conditions('bases empty', 'bases loaded')

# %% [markdown]
# # Exploring the Learned Pitch Control Distribution
# One way to support that the model is learning meaningful features is to examine the differences predicted between better and worse pitchers (OBP). We expect better pitchers to have better control.
#
# One problem with this setup is that we do not have a lot of data to work with. There might be another problem hidden in here...

# %%
conditions: dict[str, Callable[[float], bool]] = {
    'strong pitcher': (lambda p_obp: p_obp is not None and p_obp > 2/3),
    'average pitcher': (lambda p_obp: p_obp is not None and 1/3 < p_obp < 2/3),
    'weak pitcher': (lambda p_obp: p_obp is not None and p_obp < 1/3),
    'all': (lambda p_obp: True),
}

matching_pitches = defaultdict(list)

training_set, validation_set = get_pitch_control_sets(bd)

actual_distribution = defaultdict(lambda: (0, 0))  # x, y variance
for obp, (pitcher, pitch), distribution in validation_set:
    for name, condition in conditions.items():
        if condition(obp):
            matching_pitches[name].append(((pitcher, pitch), distribution))
            actual_distribution[name] = actual_distribution[name][0] + distribution[2].item(), actual_distribution[name][1] + distribution[3].item()
            
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = PitcherControl().to(device)
model.eval()
path = '../../model_weights/pitcher_control.pth'
model.load_state_dict(torch.load(path))

predicted_distribution = defaultdict(lambda: (0, 0))

for condition_name, pitches in matching_pitches.items():
    for (pitcher, pitch), distribution in pitches:
        pitcher, pitch = pitcher.to(device).unsqueeze(0), pitch.to(device).unsqueeze(0)
        predicted_dist = model(pitcher, pitch)
        predicted_distribution[condition_name] = predicted_distribution[condition_name][0] + predicted_dist[0][2].item(), predicted_distribution[condition_name][1] + predicted_dist[0][3].item()

# %%
def get_average_variance(distribution_dict, condition):
    total_x_variance, total_y_variance = distribution_dict[condition]
    num_pitches = len(matching_pitches[condition])
    if num_pitches == 0:
        return 0, 0  # Avoid division by zero if there are no matching pitches
    return total_x_variance / num_pitches, total_y_variance / num_pitches


def compare_all_conditions():
    x = np.arange(len(conditions))  # the label locations
    width = 0.2  # the width of the bars
    
    fig, ax = plt.subplots(figsize=(12, 6), dpi=300)
    
    # Get average variances for each condition
    actual_variances = [get_average_variance(actual_distribution, condition) for condition in conditions]
    predicted_variances = [get_average_variance(predicted_distribution, condition) for condition in conditions]
    
    # Separate variances for x and y
    actual_x_variances = [variance[0] for variance in actual_variances]
    actual_y_variances = [variance[1] for variance in actual_variances]
    predicted_x_variances = [variance[0] for variance in predicted_variances]
    predicted_y_variances = [variance[1] for variance in predicted_variances]
    
    # Plot actual x variances
    bars_actual_x = ax.bar(x - width, actual_x_variances, width, label='Actual X Variance', color='blue', edgecolor='black')
    # Plot predicted x variances
    bars_predicted_x = ax.bar(x, predicted_x_variances, width, label='Predicted X Variance', color='blue', hatch='\\', edgecolor='black')
    # Plot actual y variances
    bars_actual_y = ax.bar(x + width, actual_y_variances, width, label='Actual Y Variance', color='red', edgecolor='black')
    # Plot predicted y variances
    bars_predicted_y = ax.bar(x + 2 * width, predicted_y_variances, width, label='Predicted Y Variance', color='red', hatch='\\', edgecolor='black')
    
    # Add text labels for bars
    for bar in bars_actual_x + bars_predicted_x + bars_actual_y + bars_predicted_y:
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.3f}', ha='center', va='bottom')

    # Add some text for labels, title, and custom x-axis tick labels, etc.
    ax.set_xlabel('Pitcher Conditions')
    ax.set_ylabel('Variance')
    ax.set_title('Actual vs Predicted Pitch Control Variances by Condition')
    ax.set_xticks(x + width)
    ax.set_xticklabels(conditions)
    ax.set_ylim(0, max(max(actual_x_variances + predicted_x_variances + actual_y_variances + predicted_y_variances) * 1.1, 1))
    ax.legend(loc='lower right')
    
    fig.tight_layout()
    plt.show()


compare_all_conditions()

# %%
len(validation_set), len(training_set)
# Out:
# (1027, 2264)

# %% [markdown]
# # Exploring Batter Patience
# The actual distribution for batter patience on balls does not match up with the intuitive results shown in the paper. It seems that on these borderline cases, the stronger batters actually swing more often, not less. This could be due to some difference in defining the borderline pitches. More likely, this is because borderline pitches more likely to be classified as strikes by the umpires, even if they should be a ball. We're ignoring this factor currently (but the paper also does).

# %%
conditions: dict[str, Callable[[Pitch], bool]] = {
    '00': (lambda p: p.game_state.balls == 0 and p.game_state.strikes == 0),
    '01': (lambda p: p.game_state.balls == 0 and p.game_state.strikes == 1),
    '02': (lambda p: p.game_state.balls == 0 and p.game_state.strikes == 2),
    '10': (lambda p: p.game_state.balls == 1 and p.game_state.strikes == 0),
    '11': (lambda p: p.game_state.balls == 1 and p.game_state.strikes == 1),
    '12': (lambda p: p.game_state.balls == 1 and p.game_state.strikes == 2),
    '20': (lambda p: p.game_state.balls == 2 and p.game_state.strikes == 0),
    '21': (lambda p: p.game_state.balls == 2 and p.game_state.strikes == 1),
    '22': (lambda p: p.game_state.balls == 2 and p.game_state.strikes == 2),
    '30': (lambda p: p.game_state.balls == 3 and p.game_state.strikes == 0),
    '31': (lambda p: p.game_state.balls == 3 and p.game_state.strikes == 1),
    '32': (lambda p: p.game_state.balls == 3 and p.game_state.strikes == 2),
    'weak': (lambda p: bd.batters[p.batter_id].obp_percentile is not None and bd.batters[p.batter_id].obp_percentile < 1/4 and not p.get_zone().is_strike),
    'average': (lambda p: bd.batters[p.batter_id].obp_percentile is not None and 1/4 < bd.batters[p.batter_id].obp_percentile < 3/4 and not p.get_zone().is_strike),
    'strong': (lambda p: bd.batters[p.batter_id].obp_percentile is not None and bd.batters[p.batter_id].obp_percentile > 3/4 and not p.get_zone().is_strike),
    'strike weak': (lambda p: bd.batters[p.batter_id].obp_percentile is not None and bd.batters[p.batter_id].obp_percentile < 1/4 and p.get_zone().is_strike),
    'strike average': (lambda p: bd.batters[p.batter_id].obp_percentile is not None and 1/4 < bd.batters[p.batter_id].obp_percentile < 3/4 and p.get_zone().is_strike),
    'strike strong': (lambda p: bd.batters[p.batter_id].obp_percentile is not None and bd.batters[p.batter_id].obp_percentile > 3/4 and p.get_zone().is_strike),
    'bases empty': (lambda p: not p.game_state.first and not p.game_state.second and not p.game_state.third),
    'bases loaded': (lambda p: p.game_state.first and p.game_state.second and p.game_state.third),
}

matching_pitches = defaultdict(list)

actual_distribution = defaultdict(float)

training_dataset, test_dataset = get_batter_patience_set(bd)

for pitch_idx, pitch_data, batter_swung in tqdm(test_dataset):
    for name, condition in conditions.items():
        if condition(bd.pitches[pitch_idx]):
            matching_pitches[name].append(bd.pitches[pitch_idx])
            actual_distribution[name] += batter_swung.item()
# Out:
#   0%|          | 0/831338 [00:00<?, ?it/s]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BatterSwings().to(device)
path = '../../model_weights/batter_patience.pth'
model.load_state_dict(torch.load(path))
model.eval()

predicted_distribution = defaultdict(float)

for condition_name, pitches in matching_pitches.items():
    conditional_dataset = PitchDataset(bd, map_to=lambda idx, p: batter_patience_map(bd, idx, p), pitches=pitches)
    dataloader = DataLoader(conditional_dataset, batch_size=128)
    for pitch_idx, data, batter_swung in tqdm(dataloader, desc=condition_name):
        data = [t.to(device) for t in data]
        output = model.forward(*data)
        predicted_distribution[condition_name] += output.sum().item()

# %%
def compare_conditions(conds: list[str]):
    actual_probabilities = [actual_distribution[cond] / len(matching_pitches[cond]) * 100 for cond in conds]
    predicted_probabilities = [predicted_distribution[cond] / len(matching_pitches[cond]) * 100 for cond in conds]

    x = np.arange(len(conds))
    width = 0.35

    fig, ax = plt.subplots(dpi=300)
    rects1 = ax.bar(x - width/2, actual_probabilities, width, label='Actual', color='blue')
    rects2 = ax.bar(x + width/2, predicted_probabilities, width, label='Predicted', color='red')

    ax.set_xlabel('Conditions')
    ax.set_ylabel('Swing Probability (%)')
    ax.set_title('Comparison of Actual and Predicted Swing Probabilities')
    ax.set_xticks(x)
    ax.set_xticklabels(conds)
    ax.legend()

    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate('%.2f%%' % height, xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3), textcoords="offset points", ha='center', va='bottom', rotation=90, fontsize=6)

    autolabel(rects1)
    autolabel(rects2)

    fig.tight_layout()
    plt.ylim(0, 100)
    plt.show()

compare_conditions(['00', '01', '02', '10', '11', '12', '20', '21', '22', '30', '31', '32'])
compare_conditions(['weak', 'average', 'strong'])
# compare_conditions(['strike weak', 'strike average', 'strike strong'])
compare_conditions(['bases empty', 'bases loaded'])

# %% [markdown]
# # Small Probability Simulation

# %%
import random

def simulate_win(trials): 
    wins = 0
    for _ in range(trials):
        successes = 0
        fails = 0
        while fails < 3 and successes < 3:
            if random.random() < 0.25:
                successes += 1
            else:
                fails += 1
        if successes == 3:
            wins += 1
    return wins / trials

# Set the number of trials (higher number provides a more accurate estimate)
trials = 1000000

# Simulate and print the estimated probability
probability = simulate_win(trials)
print(f'Estimated probability of winning: {probability:.3f}')
# Out:
# Estimated probability of winning: 0.104
